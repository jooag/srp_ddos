# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('processed/train_data.csv').loc[0:400000]

# %%
Y=df['label'].to_numpy()

# %%
Y.shape
# Out:
# (400001,)

# %%
X=np.arange(0, Y.shape[0])

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax.scatter(X, Y, s=0.01, alpha=0.2)

# %%
df = pd.read_csv('processed/test_data.csv')
Y=df['label'].to_numpy()
X=np.arange(0, Y.shape[0])
fig, ax = plt.subplots(figsize=(20, 5))
ax.scatter(X, Y, s=0.01, alpha=0.2)
