# %%
import os
while not os.path.exists('ddos_learner'):
    os.chdir('../..')

# %%
import ddos_learner
import ddos_learner.common
import ddos_learner.ton.dataset

# %%
train_ds = ddos_learner.ton.dataset.TONIoTDataset()
test_ds = ddos_learner.ton.dataset.TONIoTDataset(False)

# %%
from river.tree import HoeffdingTreeClassifier
from river.ensemble import SRPClassifier

# %%
model = SRPClassifier(HoeffdingTreeClassifier())

# %%
ddos_learner.common.train(model, train_ds, test_ds, 400000, step_size=5000, subpath='srp_htd_ton')
# Out:
# Training initiated.
# At 1000.
# Acc: 0.70. Prec: 0.97. Recl: 0.71. F1: 0.82
# At 2000.
# Acc: 0.71. Prec: 0.98. Recl: 0.71. F1: 0.82
# At 3000.
# Acc: 0.71. Prec: 0.99. Recl: 0.71. F1: 0.82
# At 4000.
# Acc: 0.70. Prec: 0.98. Recl: 0.70. F1: 0.82
# At 5000.
# Acc: 0.70. Prec: 0.98. Recl: 0.70. F1: 0.82
# At 6000.
# Acc: 0.70. Prec: 0.98. Recl: 0.70. F1: 0.81
# At 7000.
# Acc: 0.70. Prec: 0.98. Recl: 0.70. F1: 0.82
# At 8000.
# Acc: 0.70. Prec: 0.99. Recl: 0.70. F1: 0.82
# At 9000.
# Acc: 0.69. Prec: 0.98. Recl: 0.69. F1: 0.81
# At 10000.
# Acc: 0.00. Prec: 0.00. Recl: 0.00. F1: 0.00
# At 11000.
# Acc: 0.00. Prec: 0.00. Recl: 0.00. F1: 0.00

# %%
test_ds = ddos_learner.ton.dataset.TONIoTDataset(False)

# %%
ddos_learner.common.test(test_ds, 20000, 'srp_htd_ton')
# Out:
# 1680619003
# At 100
# At 200
# At 300
# At 400
# At 500
# At 600
# At 700
# At 800
# At 900
# At 1000
# At 1100
# At 1200
# At 1300
# At 1400
# At 1500
# At 1600
# At 1700
# At 1800
# At 1900
# At 2000
# At 2100
# At 2200
# At 2300
# At 2400
# At 2500
# At 2600
# At 2700
# At 2800
# At 2900
# At 3000
# At 3100
# At 3200
# At 3300
# At 3400
# At 3500
# At 3600
# At 3700
# At 3800
# At 3900
# At 4000
# At 4100
# At 4200
# At 4300
# At 4400
# At 4500
# At 4600
# At 4700
# At 4800
# At 4900
# At 5000
# At 5100
# At 5200
# At 5300
# At 5400
# At 5500
# At 5600
# At 5700
# At 5800
# At 5900
# At 6000
# At 6100
# At 6200
# At 6300
# At 6400
# At 6500
# At 6600
# At 6700
# At 6800
# At 6900
# At 7000
# At 7100
# At 7200
# At 7300
# At 7400
# At 7500
# At 7600
# At 7700
# At 7800
# At 7900
# At 8000
# At 8100
# At 8200
# At 8300
# At 8400
# At 8500
# At 8600
# At 8700
# At 8800
# At 8900
# At 9000
# At 9100
# At 9200
# At 9300
# At 9400
# At 9500
# At 9600
# At 9700
# At 9800
# At 9900
# At 10000
# At 10100
# At 10200
# At 10300
# At 10400
# At 10500
# At 10600
# At 10700
# At 10800
# At 10900
# At 11000
# At 11100
# At 11200
# At 11300
# At 11400
# At 11500
# At 11600
# At 11700
# At 11800
# At 11900
# At 12000
# At 12100
# At 12200
# At 12300
# At 12400
# At 12500
# At 12600
# At 12700
# At 12800
# At 12900
# At 13000
# At 13100
# At 13200
# At 13300
# At 13400
# At 13500
# At 13600
# At 13700
# At 13800
# At 13900
# At 14000
# At 14100
# At 14200
# At 14300
# At 14400
# At 14500
# At 14600
# At 14700
# At 14800
# At 14900
# At 15000
# At 15100
# At 15200
# At 15300
# At 15400
# At 15500
# At 15600
# At 15700
# At 15800
# At 15900
# At 16000
# At 16100
# At 16200
# At 16300
# At 16400
# At 16500
# At 16600
# At 16700
# At 16800
# At 16900
# At 17000
# At 17100
# At 17200
# At 17300
# At 17400
# At 17500
# At 17600
# At 17700
# At 17800
# At 17900
# At 18000
# At 18100
# At 18200
# At 18300
# At 18400
# At 18500
# At 18600
# At 18700
# At 18800
# At 18900
# At 19000
# At 19100
# At 19200
# At 19300
# At 19400
# At 19500
# At 19600
# At 19700
# At 19800
# At 19900
